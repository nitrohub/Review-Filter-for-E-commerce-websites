# %%
import nltk
nltk.download('punkt')
# !pip install TextBlob
from pandas import DataFrame
from textblob import TextBlob
import pandas as pd
import nltk
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-07a59422-f934-49da-a973-82a9ba632fed" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07a59422-f934-49da-a973-82a9ba632fed">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Labelleddataset.csv to Labelleddataset (1).csv

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['Labelleddataset.csv']))
df2.head()
# Out:
#    decision  ...                                               text
# 0  truthful  ...  We stayed for a one night getaway with family ...
# 1  truthful  ...  Triple A rate with upgrade to view room was le...
# 2  truthful  ...  This comes a little late as I'm finally catchi...
# 3  truthful  ...  The Omni Chicago really delivers on all fronts...
# 4  truthful  ...  I asked for a high floor away from the elevato...
#
# [5 rows x 5 columns]

# %%
#NN noun singular
#NNS noun plural
#NNP proper noun singular
#NNPS proper noun plural
Label          =[]
hotel_name     =[]
polarity       =[]
source         =[]
review         =[]
noun_proportion=[]
def test():
  Sr_no=0
  for i in df2['text']: #for each Review
    text = i
    blob = TextBlob(text)
    tagged_words=blob.tags
    count=0
    #totl=0
    for word,tag in tagged_words:
    #  totl+=1
      if tag in ["NN","NNS","NNP","NNPS"]:
        count+=1
        # print(f'{word} => {tag}')    
    # if(count/totl>=0.4):
    polarity.append(df2['polarity'][Sr_no])
    Label.append(df2['decision'][Sr_no])
    hotel_name.append(df2['hotel'][Sr_no])
    source.append(df2['source'][Sr_no])
    review.append(df2['text'][Sr_no])
    print(count)
    noun_proportion.append(count/len(i.split()))
    # print(f'{Sr_no}=>{df2['polarity'][Sr_no]}=>{df2['decision'][Sr_no]}=>{count/len(i.split())}')
    Sr_no+=1
    
  dataset = {'Label':Label,
             'Polarity':polarity,
             'Hotel':hotel_name,
             'Source':source,
             'Review':review,
             'Noun Proportion':noun_proportion
  }
  df = DataFrame(dataset, columns= ['Label', 'Polarity','Hotel','Source','Review','Noun Proportion'])
  df.to_csv(r'Noun_calculated.csv', index = None, header=True)

# %%
test()
# Out:
# 31
# 18
# 50
# 46
# 15
# 48
# 39
# 38
# 37
# 29
# 70
# 30
# 59
# 24
# 95
# 18
# 16
# 12
# 51
# 23
# 19
# 27
# 9
# 29
# 23
# 50
# 15
# 16
# 45
# 27
# 9
# 33
# 27
# 82
# 21
# 16
# 12
# 21
# 31
# 16
# 25
# 38
# 61
# 30
# 12
# 37
# 26
# 25
# 23
# 32
# 26
# 42
# 91
# 16
# 54
# 25
# 17
# 70
# 12
# 23
# 27
# 59
# 102
# 30
# 59
# 77
# 117
# 30
# 16
# 9
# 21
# 27
# 40
# 63
# 27
# 29
# 29
# 43
# 21
# 28
# 10
# 32
# 52
# 42
# 52
# 14
# 19
# 29
# 29
# 34
# 16
# 24
# 26
# 24
# 16
# 10
# 19
# 41
# 45
# 43
# 27
# 18
# 13
# 29
# 26
# 39
# 26
# 29
# 37
# 25
# 55
# 23
# 20
# 23
# 27
# 13
# 20
# 33
# 43
# 25
# 21
# 14
# 41
# 93
# 23
# 25
# 43
# 23
# 26
# 27
# 11
# 32
# 42
# 20
# 15
# 13
# 31
# 52
# 29
# 36
# 41
# 47
# 28
# 30
# 26
# 17
# 32
# 58
# 15
# 26
# 30
# 39
# 13
# 11
# 50
# 39
# 26
# 68
# 42
# 102
# 37
# 26
# 59
# 42
# 31
# 21
# 31
# 30
# 12
# 26
# 32
# 50
# 34
# 29
# 31
# 15
# 58
# 24
# 23
# 47
# 20
# 16
# 36
# 47
# 62
# 39
# 118
# 23
# 13
# 18
# 48
# 16
# 23
# 23
# 23
# 31
# 23
# 33
# 29
# ...
